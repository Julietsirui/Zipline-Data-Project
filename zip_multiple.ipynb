# %%
import os
import glob
import pandas as pd

import pandas
import numpy as np

import csv

from pandas import DataFrame

import matplotlib.pyplot as plt

import seaborn as sb

# %%
os.chdir("C:\\Users\\Sirui\\Desktop\\Zipline\\flight files")
fileList = glob.glob("*.csv")
NList1 = []
EList2 = []
DList3 = []
len(fileList)
# Out:
# 448

# %%
for filename in fileList:
    
    df = pandas.read_csv(filename,header = None)
    df1 = df[[16]]
    df1 = df1.drop([0])
    df1 = df1.convert_objects(convert_numeric = True)
    ind_poMaxN = np.max(df1)
    ind_poMaxN = str(ind_poMaxN.tolist()[0])
    ind_poMaxN = float("".join(ind_poMaxN))
    print ind_poMaxN
    NList1.append(ind_poMaxN)
    
    df2 = df[[17]]
    df2 = df2.drop([0])
    df2 = df2.convert_objects(convert_numeric = True)
    ind_poMaxE = np.max(df2)
    ind_poMaxE = str(ind_poMaxE.tolist()[0])
    ind_poMaxE = float("".join(ind_poMaxE))
    EList2.append(ind_poMaxE)
    
    df3 = df[[18]]
    df3 = df3.drop([0])
    df3 = df3.convert_objects(convert_numeric = True)
    ind_poMaxD = np.max(df3)
    ind_poMaxD = str(ind_poMaxD.tolist()[0])
    ind_poMaxD = float("".join(ind_poMaxD))
    DList3.append(ind_poMaxD)
    #print ind_poMaxN
# Out:
# C:\Users\Sirui\Anaconda2\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#
# C:\Users\Sirui\Anaconda2\lib\site-packages\ipykernel_launcher.py:15: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   from ipykernel import kernelapp as app
# C:\Users\Sirui\Anaconda2\lib\site-packages\ipykernel_launcher.py:23: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# 4.4721103
# 4.4928823
# ...

# %%
NList1
# Out:
# [4.4721103,
#  4.4928823,
#  4.4097853,
#  4.154534,
#  4.2973084,
#  4.090949,
#  4.5028358,
#  5.0423927,
#  4.4158435,
#  5.060804,
#  4.717477,
#  4.0282702,
#  4.064686,
#  4.0724993,
#  4.0100946,
#  4.0756445,
#  10.646661,
#  4.246541,
#  5.707479,
#  4.5745697,
#  4.6035843,
#  4.4202275,
#  5.1102667,
#  4.1851053,
#  4.8818383,
#  4.937015,
#  4.236409,
#  4.157355,
#  5.6261387,
#  3.9773552,
#  3.949391,
#  4.4578032,
#  4.0387993,
#  8.300195,
#  4.1711345,
#  7.880546,
#  4.179634,
#  8.8829775,
#  4.880125,
#  5.109476,
#  4.672127,
#  5.1910086,
#  4.8418007,
#  4.2047014,
#  4.7264285,
#  4.2490993,
#  4.663867,
#  4.256087,
#  4.591983,
#  4.941884,
#  4.50761,
#  3.9640024,
#  4.2680006,
#  4.0409904,
#  4.826571,
#  5.125581,
#  4.468562,
#  4.0574737,
#  4.992044,
#  4.227315,
#  5.5512934,
#  4.5225415,
#  4.392919,
#  5.297669,
#  4.4349027,
#  4.7605796,
#  4.618258,
#  4.21157,
#  4.208862,
#  4.3534255,
#  4.596597,
#  5.6275234,
#  4.4514413,
# ...

# %%
DList3
# Out:
# [5.4924536,
#  5.5378923,
#  5.564977,
#  5.4697194,
#  5.5058045,
#  5.4925942,
#  5.547546,
#  5.494342,
#  5.556516,
#  5.591869,
#  5.5806293,
#  5.5782423,
#  5.577441,
#  5.6083407,
#  5.514052,
#  5.5669675,
#  5.5824847,
#  5.5459585,
#  5.5801096,
#  5.594253,
#  5.5072274,
#  5.539365,
#  5.5722938,
#  5.6019344,
#  5.6135726,
#  5.582511,
#  5.550196,
#  5.5257463,
#  5.5076256,
#  5.4938803,
#  5.4500284,
#  5.599468,
#  5.4733934,
#  5.5088286,
#  5.5548573,
#  5.5687747,
#  5.5504193,
#  6.0764213,
#  5.594363,
#  5.506691,
#  5.593113,
#  5.5675015,
#  5.571937,
#  5.540372,
#  5.5851903,
#  5.6255145,
#  5.5684137,
#  5.5827394,
#  5.584298,
#  5.5747013,
#  5.494075,
#  5.4534426,
#  5.5482507,
#  5.466743,
#  5.5689373,
#  5.6175103,
#  5.605714,
#  5.5327888,
#  5.628793,
#  5.5706267,
#  5.588935,
#  5.5869093,
#  5.572604,
#  5.5813284,
#  5.5854664,
#  5.554377,
#  5.5929055,
#  5.580374,
#  5.529232,
#  5.598412,
#  5.567931,
#  5.5983877,
#  5.5874248,
# ...

# %%
EList2
# Out:
# [6.3703237,
#  6.2148647,
#  6.2775593,
#  5.9350247,
#  5.405598,
#  5.223184,
#  6.5461397,
#  7.123452,
#  5.425265,
#  5.8974133,
#  5.687401,
#  5.605343,
#  5.493623,
#  5.692934,
#  5.2933774,
#  5.314522,
#  14.510765,
#  5.90409,
#  6.4710364,
#  5.940011,
#  5.6821475,
#  5.7124624,
#  6.3910065,
#  5.404871,
#  7.3652577,
#  7.314418,
#  5.4681525,
#  5.420671,
#  7.5272193,
#  5.1908135,
#  5.0988045,
#  6.1179695,
#  5.1364493,
#  10.330109,
#  5.4359894,
#  6.5852704,
#  5.627751,
#  10.916789,
#  7.360514,
#  6.4620786,
#  7.381032,
#  7.1160855,
#  7.703869,
#  6.144902,
#  7.926654,
#  5.507289,
#  7.3338814,
#  5.631888,
#  6.116068,
#  6.688607,
#  6.073025,
#  5.157738,
#  5.3832254,
#  5.170173,
#  7.6982827,
#  6.5103555,
#  6.6592712,
#  5.3075395,
#  6.0574155,
#  5.7416663,
#  7.6434917,
#  5.9942117,
#  5.364726,
#  7.47025,
#  5.645063,
#  6.7862287,
#  6.571572,
#  5.754019,
#  5.9722857,
#  5.912185,
#  6.4123216,
#  7.041995,
#  6.27905,
#  7.4284463,
# ...
